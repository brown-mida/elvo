# %%
import pydicom
import os

# %%
def load_scan(dirpath):
    """Loads a CT scan.

    This only loads dicom files ending in .dcm and ignores nested
    folders.

    :param dirpath: the path to a directory containing dicom (.dcm) files
    :return: a list of all dicom FileDataset objects, sorted by
        ImagePositionPatient
    """
    slices = [pydicom.read_file(dirpath + '/' + filename)
              for filename in os.listdir(dirpath)
              if filename.endswith('.dcm')]
    return sorted(slices, key=lambda x: float(x.ImagePositionPatient[2]))

# %%
dirpath = "/Users/haltriedman/Downloads/AFN5EQGSDERZCTLM ASPLUND FABIAN N/43180aa67f90657abbecd099b45fc7a1 CTA ELVO Head and Neck/CT 1mm axial brain neck cta"
scan = load_scan(dirpath)

# %%
# Out:
# [(0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141747'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432820
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-89.500']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-89.500"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141747'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282848.433092
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '2'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-88.250']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-88.250"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141747'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432818
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '3'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-87.000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-87.000"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141747'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282848.433090
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '4'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-85.750']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-85.750"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141748'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432816
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '5'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-84.500']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-84.500"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141748'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282848.433088
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '6'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-83.250']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-83.250"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141748'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432814
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '7'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-82.000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-82.000"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141748'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282848.433086
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '499'
# (0018, 1152) Exposure                            IS: '9'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 274
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '8'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '-80.750']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-80.750"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141748'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432812
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# ...
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '173'
# (0018, 1152) Exposure                            IS: '3'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 276
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '271'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '248.000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "248.000"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141814'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282846.432548
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '171'
# (0018, 1152) Exposure                            IS: '3'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 276
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '272'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '249.250']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "249.250"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0000) Group Length                        UL: 464
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20171020'
# (0008, 0013) Instance Creation Time              TM: '141814'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.296485376.1.1520282847.432822
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '43180aa67f90657abbecd099b45fc7a1'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CTA ELVO Head and Neck'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG5391'
#    (0008, 0102) Coding Scheme Designator            SH: 'GEIIS'
#    (0008, 0103) Coding Scheme Version               SH: '0'
#    (0008, 0104) Code Meaning                        LO: 'CTA ELVO Head and Neck'
#    ---------
# (0008, 103e) Series Description                  LO: '1mm axial brain neck cta'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0010, 0000) Group Length                        UL: 74
# (0010, 0010) Patient's Name                      PN: 'ASPLUND^FABIAN^N'
# (0010, 0020) Patient ID                          LO: 'AFN5EQGSDERZCTLM'
# (0010, 0030) Patient's Birth Date                DA: '19500116'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0018, 0000) Group Length                        UL: 420
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "1.250000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "0.625000"
# (0018, 0090) Data Collection Diameter            DS: "320.000000"
# (0018, 1020) Software Version(s)                 LO: 'gmp_vct.42'
# (0018, 1040) Contrast/Bolus Route                LO: 'IV'
# (0018, 1100) Reconstruction Diameter             DS: "280.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.147000"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "185.500000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '600'
# (0018, 1151) X-Ray Tube Current                  IS: '170'
# (0018, 1152) Exposure                            IS: '3'
# (0018, 1160) Filter Type                         SH: 'HEAD FILTER'
# (0018, 1170) Generator Power                     IS: '60000'
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'SOFT'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.6
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 65.625
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0020, 0000) Group Length                        UL: 276
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.296485376.1.1520282846.432546
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.296485376.1.1520282846.432547
# (0020, 0010) Study ID                            SH: ''
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '273'
# (0020, 0032) Image Position (Patient)            DS: ['-140.000', '-140.000', '250.500']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "250.500"
# (0028, 0000) Group Length                        UL: 184
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.546875', '0.546875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 1050) Window Center                       DS: "220"
# (0028, 1051) Window Width                        DS: "1000"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0000) Group Length                        UL: 8
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes]
